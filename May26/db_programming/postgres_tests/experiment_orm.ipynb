# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

# %%
DATABASE_URI = "postgresql+psycopg2://admin:admin@localhost:5432/mydb"

# %%
engine = create_engine(
    DATABASE_URI,
    echo=True)

SessionLocal = sessionmaker(
    autocommit=False,
    autoflush=False,
    bind=engine)

# %%
from sqlalchemy.orm import DeclarativeBase

class Base(DeclarativeBase):
    pass

# %%
from sqlalchemy import String, Integer, Float
from sqlalchemy import Column
class Course(Base):
    __tablename__ = 'courses'
    
    id = Column(Integer, primary_key=True)
    name = Column(String(50))
    description = Column(String(200))
    price = Column(Float)

# %%
Base.metadata.create_all(engine)
# Out:
# 2026-05-24 10:00:54,458 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-05-24 10:00:54,459 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-05-24 10:00:54,469 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-05-24 10:00:54,471 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-05-24 10:00:54,477 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-05-24 10:00:54,479 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-05-24 10:00:54,483 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-24 10:00:54,488 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-05-24 10:00:54,489 INFO sqlalchemy.engine.Engine [generated in 0.00109s] {'table_name': 'courses', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-05-24 10:00:54,493 INFO sqlalchemy.engine.Engine
# CREATE TABLE courses (
# 	id SERIAL NOT NULL,
# 	name VARCHAR(50),
# 	description VARCHAR(200),
# 	price FLOAT,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-05-24 10:00:54,494 INFO sqlalchemy.engine.Engine [no key 0.00077s] {}
# 2026-05-24 10:00:54,510 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# %%
genai_course = Course(
    name='GenAI',
    description='Generative AI Course',
    price=50000.0
)
session.add(genai_course)
session.commit()
# Out:
# 2026-05-24 10:02:32,330 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-24 10:02:32,337 INFO sqlalchemy.engine.Engine INSERT INTO courses (name, description, price) VALUES (%(name)s, %(description)s, %(price)s) RETURNING courses.id
# 2026-05-24 10:02:32,339 INFO sqlalchemy.engine.Engine [generated in 0.00230s] {'name': 'GenAI', 'description': 'Generative AI Course', 'price': 50000.0}
# 2026-05-24 10:02:32,354 INFO sqlalchemy.engine.Engine COMMIT

# %%
python_course = Course(
    name = 'Python Developer',
    description = 'Python Developer',
    price = 20000.00
)
session.add(python_course)
session.commit()
# Out:
# 2026-05-24 10:03:36,591 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-24 10:03:36,592 INFO sqlalchemy.engine.Engine INSERT INTO courses (name, description, price) VALUES (%(name)s, %(description)s, %(price)s) RETURNING courses.id
# 2026-05-24 10:03:36,593 INFO sqlalchemy.engine.Engine [cached since 64.25s ago] {'name': 'Python Developer', 'description': 'Python Developer', 'price': 20000.0}
# 2026-05-24 10:03:36,598 INFO sqlalchemy.engine.Engine COMMIT
