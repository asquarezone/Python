# %% [markdown]
# # Insall SQL Alchemy
#
# ```bash
# uv add sqlalchemy
# ```

# %%
# Create engine
from sqlalchemy import create_engine
engine = create_engine('sqlite:///studentsv2.db', echo=True)

# %%
## Create Models 
# Each Model => Table
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import DeclarativeBase

class Base(DeclarativeBase):
    pass

# student table
class Student(Base):
    __tablename__ = 'student'
    
    id = Column(Integer, primary_key=True)
    name = Column(String(100))
    email = Column(String(100))
    
    def __repr__(self):
        return f"Student(id={self.id}, name='{self.name}', email='{self.email}')"
    
class Course(Base):
    __tablename__ = 'courses'
    
    id = Column(Integer, primary_key=True)
    name = Column(String(50))
    description = Column(String(200))
    price = Column(Float)
# To create all tables 

Base.metadata.create_all(engine)
# Out:
# 2026-05-24 10:05:17,621 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-24 10:05:17,622 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("student")
# 2026-05-24 10:05:17,622 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-24 10:05:17,624 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("courses")
# 2026-05-24 10:05:17,624 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-24 10:05:17,625 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("courses")
# 2026-05-24 10:05:17,625 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-05-24 10:05:17,626 INFO sqlalchemy.engine.Engine
# CREATE TABLE courses (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(50),
# 	description VARCHAR(200),
# 	price FLOAT,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-05-24 10:05:17,627 INFO sqlalchemy.engine.Engine [no key 0.00061s] ()
# 2026-05-24 10:05:17,630 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Sessions manages DB OPerations

from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# %%
student = Student(name="Rahul", email="rahul@gmail.com")
session.add(student)
session.commit()
# Out:
# 2026-05-24 09:52:52,038 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-24 09:52:52,041 INFO sqlalchemy.engine.Engine INSERT INTO student (name, email) VALUES (?, ?)
# 2026-05-24 09:52:52,043 INFO sqlalchemy.engine.Engine [generated in 0.00142s] ('Rahul', 'rahul@gmail.com')
# 2026-05-24 09:52:52,045 INFO sqlalchemy.engine.Engine COMMIT

# %%
student = Student(name="John", email="john@gmail.com")
session.add(student)
session.commit()
# Out:
# 2026-05-24 09:53:18,478 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-24 09:53:18,480 INFO sqlalchemy.engine.Engine INSERT INTO student (name, email) VALUES (?, ?)
# 2026-05-24 09:53:18,486 INFO sqlalchemy.engine.Engine [cached since 26.44s ago] ('John', 'john@gmail.com')
# 2026-05-24 09:53:18,489 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Query

students = session.query(Student).all()
for student in students:
    print(student)
# Out:
# 2026-05-24 09:54:03,868 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-05-24 09:54:03,877 INFO sqlalchemy.engine.Engine SELECT student.id AS student_id, student.name AS student_name, student.email AS student_email
# FROM student
# 2026-05-24 09:54:03,879 INFO sqlalchemy.engine.Engine [generated in 0.00294s] ()
# Student(id=1, name='Rahul', email='rahul@gmail.com')
# Student(id=2, name='John', email='john@gmail.com')
