# %% [markdown]
# ## Co-routine
#
#
# * defining a couroutine

# %%
async def sample_coroutine():
    return "hello"

def sample_function():
    return "hello"

# %%
# calling function
sample_function()
# Out:
# 'hello'

# %%
# creating coroutine
sample_coroutine()
# Out:
# <coroutine object sample_coroutine at 0x000001ED2B0271C0>

# %%
# coroutines require event loop
import asyncio

# creates a event loop
# asyncio.run()

# %%
# non-blocking sleep
await asyncio.sleep(5)

# %% [markdown]
# # Two ways to wait for coroutines
#
# * await: waits for individual coroutine to execute and finish
# * gather: waits for set of coroutines to execute and finish in any order.

# %% [markdown]
# ##

# %% [markdown]
# ### Lets try the following
#
# * We have 10 coroutines trying to download files from internet
