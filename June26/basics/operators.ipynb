# %% [markdown]
# ## Python Operators
#
# * [Refer Here](https://www.programiz.com/python-programming/operators) for programiz

# %%
## Arthimetic operators
x = 5
y = 3
print(x + y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 2
# 125

# %%
x + y
# Out:
# 8

# %%
x = 5
x
# Out:
# 5

# %%
y = x
y
# Out:
# 5

# %%
x = 6
print(x)
print(y)
# Out:
# 6
# 5

# %%
x = 10
x
# Out:
# 10

# %%
x = x + 1
x
# Out:
# 11

# %%
x += 2 #x = x + 2
print(x)
x -= 2 # x = x - 2
print(x)
x *= 2 # x = x*2
x
# Out:
# 13
# 11
# 22

# %%
x = 5
y = 6

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x < y
# Out:
# True

# %%
x >= y
# Out:
# False

# %%
# is x between 4 and 10

x >= 4 and x <= 10
# Out:
# True

# %%
4 <= x <= 10
# Out:
# True

# %%
x = 10
y = 9

# %%
x > 5 and y > 10
# Out:
# False

# %%
x > 5 and y < 10
# Out:
# True

# %%
x > 5 or y > 10
# Out:
# True

# %%
x > 5 or y < 10
# Out:
# True

# %%
not x > 5
# Out:
# False

# %%
# convert from kilos to pounds
weight_in_kilos = 50
weight_in_pounds = 2.205 * weight_in_kilos
weight_in_pounds
# Out:
# 110.25

# %%
# pounds to kilos
weight_in_pounds = 200
weight_in_kilos = weight_in_pounds / 2.205
weight_in_kilos
# Out:
# 90.70294784580499

# %%
# even number
number = 10
number %2 == 0
# Out:
# True

# %%
number = 11
number %2 == 0
# Out:
# False
