# %% [markdown]
# # Python Datatypes
#
# * [Refer Here](https://www.programiz.com/python-programming/variables-datatypes) for the programiz article

# %%
# type function

type(5)
# Out:
# int

# %%
type(5.1)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type('hello')
# Out:
# str

# %%
# Numeric Datatypes

x = 5
type(x)
# Out:
# int

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
z = 3 + 4j
type(z)
# Out:
# complex

# %%
x = 1000

y = x ** 1000
print(y)
type(y)
# Out:
# ...
# int

# %%
y = 10/3
type(y)
# Out:
# float

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
10//0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 10//0
#
# ZeroDivisionError: integer division or modulo by zero
