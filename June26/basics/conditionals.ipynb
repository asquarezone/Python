# %% [markdown]
# ## Python conditionals

# %%
number = 10
result = number % 2
print("even")
print("odd")
# Out:
# even
# odd

# %% [markdown]
# ## if
# * [Refer Here](https://www.programiz.com/python-programming/if-elif-else)

# %%
number = 10
result = number % 2
if result == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
number = 10
result = number % 2
if result == 0:
    print("even")
if result !=0:
    print("odd")
# Out:
# even

# %%
average = 80
if average > 70:
    print("Grade 1")
elif 60 < average <= 70:
    print("Grade 2")
elif 50 < average <= 60:
    print("Grade 3")
else:
    print("Grade 4")
# Out:
# Grade 1

# %%
average = 80
if average > 70:
    print("Grade 1")
if 60 < average <= 70:
    print("Grade 2")
if 50 < average <= 60:
    print("Grade 3")
if average <= 50:
    print("Grade 4")
# Out:
# Grade 1

# %%
# Tax calculations

income_in_lakhs = 12.5
tax = 0
if income_in_lakhs <= 12:
    tax = 0
    print("Hurray No Tax")
else:
    income_in_lakhs = income_in_lakhs - 0.75 # standard deduction
    # you have taxable income
    if income_in_lakhs > 4:
        percentage = 5 / 100
        max = 8
        min = 4
        if income_in_lakhs > max:
            eligible_amount_in_this_slab = 4
        else:
            eligible_amount_in_this_slab = income_in_lakhs - min
        tax += eligible_amount_in_this_slab * percentage
        
    if income_in_lakhs > 8:
        percentage = 10 / 100
        max = 12
        min = 8
        if income_in_lakhs > max:
            eligible_amount_in_this_slab = 4
        else:
            eligible_amount_in_this_slab = income_in_lakhs - min
        tax += eligible_amount_in_this_slab * percentage
    if income_in_lakhs > 12:
        percentage = 15/100
        max = 16
        min = 12
        if income_in_lakhs > max:
            eligible_amount_in_this_slab = 4
        else:
            eligible_amount_in_this_slab = income_in_lakhs - min
        tax += eligible_amount_in_this_slab * percentage
    if income_in_lakhs > 16:
        percentage = 20/100
        max = 20
        min = 16
        if income_in_lakhs > max:
            eligible_amount_in_this_slab = 4
        else:
            eligible_amount_in_this_slab = income_in_lakhs - min
        tax += eligible_amount_in_this_slab * percentage
    if income_in_lakhs > 20:
        percentage = 25/100
        max = 24
        min = 20
        if income_in_lakhs > max:
            eligible_amount_in_this_slab = 4
        else:
            eligible_amount_in_this_slab = income_in_lakhs - min
        tax += eligible_amount_in_this_slab * percentage
    if income_in_lakhs > 24:
        percentage = 30 / 100
        min = 24
        eligible_amount_in_this_slab = income_in_lakhs - min
        tax += eligible_amount_in_this_slab * percentage

tax = tax * 100000
tax
# Out:
# 57499.99999999999
