# %% [markdown]
# ## Python conditionals

# %%
number = 10
result = number % 2
print("even")
print("odd")
# Out:
# even
# odd

# %% [markdown]
# ## if
# * [Refer Here](https://www.programiz.com/python-programming/if-elif-else)

# %%
number = 10
result = number % 2
if result == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
number = 10
result = number % 2
if result == 0:
    print("even")
if result !=0:
    print("odd")
# Out:
# even

# %%
average = 80
if average > 70:
    print("Grade 1")
elif 60 < average <= 70:
    print("Grade 2")
elif 50 < average <= 60:
    print("Grade 3")
else:
    print("Grade 4")
# Out:
# Grade 1

# %%
average = 80
if average > 70:
    print("Grade 1")
if 60 < average <= 70:
    print("Grade 2")
if 50 < average <= 60:
    print("Grade 3")
if average <= 50:
    print("Grade 4")
# Out:
# Grade 1
